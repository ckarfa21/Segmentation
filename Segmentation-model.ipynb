# %% [markdown]
# Model pour la segmentation d images

# %%
import tensorflow as tf
import os 
import matplotlib.pyplot as plt 
import seaborn as sns
import cv2
from sklearn.model_selection import train_test_split
import numpy as np 
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from math import log10, sqrt
from google.colab import drive
#drive mount, sert à stocker les données dans le drive sinon ce nest pas possible d'utiliser Google collab.
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
IMG_SHAPE =(512,512)
IMG=(512,512,1)

# %%
def display_sample(display_list):
    """Show side-by-side an input image,
    the ground truth and the prediction.
    """
    plt.figure(figsize=(18, 18))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(display_list[i],cmap='gray')
        plt.axis('off')
    plt.show()

# %%
images=[]
masks=[]

folders=[]
for root, dirs, files in os.walk("/content/gdrive/My Drive/segmentation/data_seg"):
  folders.append(dirs)

print("========================")

for root, dirs, files in os.walk(f'/content/gdrive/My Drive/segmentation/data_seg'):
  filenames=files

filenames.sort()

for name in filenames:
  imgPath=f'/content/gdrive/My Drive/segmentation/data_seg/{name}'
  print(imgPath)
  img=load_img(imgPath,target_size=IMG_SHAPE,color_mode='grayscale')
  x=img_to_array(img)
  images.append(x)
print("========================")


for root, dirs, files in os.walk(f'/content/gdrive/My Drive/segmentation/data_seg'):

  filenames=files

filenames.sort()
for name in filenames:
  imgPath=f'/content/gdrive/My Drive/segmentation/data_seg/label/{name}'
  print(imgPath)
  img=load_img(imgPath,target_size=IMG_SHAPE,color_mode='grayscale')
  x=img_to_array(img)
  masks.append(x)

# %%
plt.imshow(masks[0].reshape(IMG_SHAPE))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-e996b690c4b6> in <module>()
# ----> 1 plt.imshow(masks[0].reshape(IMG_SHAPE))
#
# IndexError: list index out of range

# %%
plt.imshow(images[0].reshape(IMG_SHAPE))
